# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_co2 = pd.read_csv(r"C:\Users\Infinix X2\Documents\SEMESTER 8\Data Science\DATASET\co2.csv")
df_co2.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
df_co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
plt.figure(figsize=(12, 8))

# Membuat histogram bertumpuk
plt.hist([df_co2_co2_co2_co2_co2_co2[df_co2['Transmission'] == transmission]['Engine Size(L)'] for transmission in transmissions],
         bins=50, 
         alpha=0.5, 
         label=transmissions,
         stacked=True)

plt.xlabel('Engine Size (L)', fontsize=15)
plt.ylabel('Number of Cars', fontsize=15)
plt.title('Stacked Histogram of Engine Size by Transmission', fontsize=20)
plt.legend(title='Transmission')
plt.grid()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_co2, x='Engine Size(L)', y='Transmission', hue='Transmission', alpha=0.7)
plt.title('Engine Size vs Transmission', fontsize=20)
plt.xlabel('Engine Size (L)', fontsize=15)
plt.ylabel('Transmission', fontsize=15)
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Pastikan df_co2 sudah didefinisikan sebelumnya
plt.figure(figsize=(12, 8))
df_co2.boxplot(column='Engine Size(L)', by='Transmission', grid=True, fontsize=8)
plt.suptitle('Engine Size Distribution by Transmission', fontsize=10)
plt.xlabel('Transmission', fontsize=15)
plt.ylabel('Engine Size (L)', fontsize=15)
plt.xticks(rotation=30)
plt.show()

# %%
df_co2.hist(column='CO2 Emissions(g/km)', bins=50, grid=False, color='green')
plt.xlabel('CO2 Emissions (g/km)')
# Out:
# Text(0.5, 0, 'CO2 Emissions (g/km)')

# %%
df_co2.hist(column='Fuel Consumption Comb (L/100 km)', bins=50, grid=False, color='green')
plt.xlabel('Fuel Consumption Comb (L/100 km)')
# Out:
# Text(0.5, 0, 'Fuel Consumption Comb (L/100 km)')

# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# Encode 'Transmission' column to numerical values
le = LabelEncoder()
df_co2['Transmission_encoded'] = le.fit_transform(df_co2['Transmission'])

# Calculate correlation
print(df_co2[['Transmission_encoded', 'Cylinders']].corr())

# Plot regression
sns.regplot(x="Transmission_encoded", y="Cylinders", data=df_co2)
plt.ylim(0,)
plt.show()
# Out:
#                       Transmission_encoded  Cylinders
# Transmission_encoded              1.000000  -0.270011
# Cylinders                        -0.270011   1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Encode 'Fuel Type' column to numerical values
le_fuel = LabelEncoder()
df_co2['Fuel Type_encoded'] = le_fuel.fit_transform(df_co2['Fuel Type'])

# Calculate correlation between 'Fuel Type_encoded' and 'Cylinders'
print(df_co2[['Fuel Type_encoded', 'Cylinders']].corr())

# Plot regression between 'Fuel Type_encoded' and 'Cylinders'
sns.regplot(x="Fuel Type_encoded", y="Cylinders", data=df_co2)
plt.ylim(0,)
plt.xlabel('Fuel Type')
plt.ylabel('Cylinders')
plt.title('Regression Plot of Fuel Type vs Cylinders')
plt.show()
# Out:
#                    Fuel Type_encoded  Cylinders
# Fuel Type_encoded           1.000000   0.125175
# Cylinders                   0.125175   1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menggunakan seaborn untuk membuat boxplot hanya untuk kolom 'Transmission'
plt.figure(figsize=(12, 8))
sns.boxplot(y=df_co2['Transmission'])
plt.title('Boxplot of Transmission')
plt.ylabel('Transmission')
plt.show()

# %%
df_co2.describe()
# Menampilkan ringkasan statistik
summary_stats = df_co2.describe()
print(summary_stats)
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
import matplotlib.pyplot as plt

# Mengambil nilai rata-rata, median, dan standar deviasi
mean_values = summary_stats.loc['mean']
median_values = summary_stats.loc['50%']
std_values = summary_stats.loc['std']

# Membuat DataFrame untuk visualisasi
summary_df = pd.DataFrame({
    'Mean': mean_values,
    'Median': median_values,
    'Std Dev': std_values
})

# Membuat diagram batang
summary_df.plot(kind='bar', figsize=(12, 8), alpha=0.7)
plt.title('Summary Statistics of CO2 Data', fontsize=20)
plt.ylabel('Value', fontsize=15)
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12, 8))
df_co2.boxplot(grid=True)
plt.title('Box Plot of CO2 Data', fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Engine Size(L)', y='Cylinders', data=df_co2)
# Out:
# <AxesSubplot: xlabel='Engine Size(L)', ylabel='Cylinders'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Mengambil kolom numerik dari DataFrame
numeric_columns = df_co2.select_dtypes(include=['float64', 'int64']).columns

# Membuat box plot untuk setiap kolom numerik
plt.figure(figsize=(15, 10))
for i, column in enumerate(numeric_columns):
    plt.subplot(len(numeric_columns), 1, i + 1)  # Membuat subplot
    df_co2.boxplot(column=column)
    plt.title(f'Box Plot of {column}', fontsize=15)
    plt.grid()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Misalkan df adalah DataFrame Anda
transmission_counts = df_co2['Transmission'].value_counts()
engine_size_counts = df_co2['Engine Size(L)'].value_counts()

# Menampilkan proporsi untuk Transmission
print(transmission_counts)

# Menampilkan proporsi untuk Engine Size
print(engine_size_counts)

# Membuat pie chart untuk Transmission
plt.figure(figsize=(8, 6))
plt.pie(transmission_counts, labels=transmission_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Transmission Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# Membuat pie chart untuk Engine Size
plt.figure(figsize=(8, 6))
plt.pie(engine_size_counts, labels=engine_size_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Engine Sizes')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# AS6     1324
# AS8     1211
# M6       901
# A6       789
# A8       490
# AM7      445
# A9       339
# AS7      319
# AV       295
# M5       193
# AS10     168
# AM6      132
# AV7      118
# AV6      113
# M7        91
# A5        84
# AS9       77
# A4        65
# AM8       62
# A7        53
# AV8       39
# A10       31
# AS5       26
# AV10      11
# AM5        4
# AM9        3
# AS4        2
# Name: Transmission, dtype: int64
# 2.0    1460
# 3.0     804
# 3.6     536
# 3.5     529
# 2.5     423
# 2.4     346
# 1.6     302
# 5.3     290
# 1.8     216
# 1.4     211
# 5.0     207
# 1.5     207
# 4.0     198
# 6.2     162
# 4.4     131
# 5.7     116
# 3.8     114
# 3.7     112
# 2.7      99
# 6.0      94
# 3.3      85
# 4.7      78
# 3.4      52
# 5.5      52
# 4.3      52
# 2.3      51
# 5.2      48
# 6.4      46
# 5.6      36
# 3.2      35
# 4.8      32
# 4.6      32
# 6.6      29
# 1.2      25
# 6.7      25
# 2.8      24
# 2.9      23
# 1.0      18
# 6.5      18
# 4.2      14
# ...

# %%
# Menghitung matriks korelasi
correlation_matrix = df_co2.corr()
print(correlation_matrix)

# Mengatur ukuran figure
plt.figure(figsize=(12, 8))

# Membuat heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})

# Menambahkan judul
plt.title('Correlation Matrix', fontsize=20)
plt.show()
# Out:
# C:\Users\Infinix X2\AppData\Local\Temp\ipykernel_7520\1420762644.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_co2.corr()
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                          1.000000   0.927653
# Cylinders                               0.927653   1.000000
# Fuel Consumption City (L/100 km)        0.831379   0.800702
# Fuel Consumption Hwy (L/100 km)         0.761526   0.715252
# Fuel Consumption Comb (L/100 km)        0.817060   0.780534
# Fuel Consumption Comb (mpg)            -0.757854  -0.719321
# CO2 Emissions(g/km)                     0.851145   0.832644
# Transmission_encoded                   -0.322389  -0.270011
# Fuel Type_encoded                       0.058296   0.125175
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style untuk seaborn
sns.set_theme(style="whitegrid")

# 1. Histogram distribusi CO2 Emissions
plt.figure(figsize=(8,5))
sns.histplot(df_co2["CO2 Emissions(g/km)"], bins=30, kde=True, color="blue")
plt.title("Distribusi Emisi CO2 Kendaraan")
plt.xlabel("CO2 Emissions (g/km)")
plt.ylabel("Frekuensi")
plt.show()

# 2. Scatter plot Fuel Consumption vs CO2 Emissions
plt.figure(figsize=(8,5))
sns.scatterplot(x=df_co2["Fuel Consumption Comb (L/100 km)"], y=df_co2["CO2 Emissions(g/km)"], alpha=0.5, color="red")
plt.title("Konsumsi Bahan Bakar vs Emisi CO2")
plt.xlabel("Fuel Consumption (L/100 km)")
plt.ylabel("CO2 Emissions (g/km)")
plt.show()

# 3. Bar chart rata-rata emisi CO2 berdasarkan kelas kendaraan
plt.figure(figsize=(10,6))
avg_co2_per_class = df_co2.groupby("Vehicle Class")["CO2 Emissions(g/km)"].mean().sort_values()
sns.barplot(x=avg_co2_per_class, y=avg_co2_per_class.index, palette="viridis")
plt.title("Rata-rata Emisi CO2 per Kelas Kendaraan")
plt.xlabel("Rata-rata CO2 Emissions (g/km)")
plt.ylabel("Vehicle Class")
plt.show()

# 4. Scatter plot Engine Size vs CO2 Emissions
plt.figure(figsize=(8,5))
sns.scatterplot(x=df_co2["Engine Size(L)"], y=df_co2["CO2 Emissions(g/km)"], alpha=0.5, color="green")
plt.title("Ukuran Mesin vs Emisi CO2")
plt.xlabel("Engine Size (L)")
plt.ylabel("CO2 Emissions (g/km)")
plt.show()

# 5. Bar chart Emisi CO2 berdasarkan jenis bahan bakar
plt.figure(figsize=(8,5))
avg_co2_per_fuel = df_co2.groupby("Fuel Type")["CO2 Emissions(g/km)"].mean().sort_values()
sns.barplot(x=avg_co2_per_fuel, y=avg_co2_per_fuel.index, palette="magma")
plt.title("Rata-rata Emisi CO2 per Jenis Bahan Bakar")
plt.xlabel("Rata-rata CO2 Emissions (g/km)")
plt.ylabel("Fuel Type")
plt.show()
# Out:
# C:\Users\Infinix X2\AppData\Local\Temp\ipykernel_7520\935137963.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_co2_per_class, y=avg_co2_per_class.index, palette="viridis")
# C:\Users\Infinix X2\AppData\Local\Temp\ipykernel_7520\935137963.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_co2_per_fuel, y=avg_co2_per_fuel.index, palette="magma")

# %%
# 1. Heatmap Korelasi Antar Variabel Numerik
plt.figure(figsize=(10,6))
correlation_matrix = df_co2.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap Korelasi Antar Variabel")
plt.show()

# 2. Boxplot Emisi CO2 berdasarkan Jenis Transmisi
plt.figure(figsize=(12,6))
sns.boxplot(x=df_co2["Transmission"], y=df_co2["CO2 Emissions(g/km)"], palette="Set2")c
plt.xticks(rotation=45)
plt.title("Distribusi Emisi CO2 Berdasarkan Jenis Transmisi")
plt.xlabel("Transmission Type")
plt.ylabel("CO2 Emissions (g/km)")
plt.show()

# 3. Merek Kendaraan dengan Emisi CO2 Terendah dan Tertinggi
avg_co2_per_make = df_co2.groupby("Make")["CO2 Emissions(g/km)"].mean().sort_values()
lowest_co2_makes = avg_co2_per_make.head(10)  # 10 Merek dengan Emisi Terendah
highest_co2_makes = avg_co2_per_make.tail(10) # 10 Merek dengan Emisi Tertinggi

# Plot 10 merek dengan emisi CO2 terendah
plt.figure(figsize=(10,5))
sns.barplot(x=lowest_co2_makes, y=lowest_co2_makes.index, palette="Greens_r")
plt.title("10 Merek Kendaraan dengan Emisi CO2 Terendah")
plt.xlabel("Rata-rata CO2 Emissions (g/km)")
plt.ylabel("Make")
plt.show()

# Plot 10 merek dengan emisi CO2 tertinggi
plt.figure(figsize=(10,5))
sns.barplot(x=highest_co2_makes, y=highest_co2_makes.index, palette="Reds_r")
plt.title("10 Merek Kendaraan dengan Emisi CO2 Tertinggi")
plt.xlabel("Rata-rata CO2 Emissions (g/km)")
plt.ylabel("Make")
plt.show()
# Out:
# C:\Users\Infinix X2\AppData\Local\Temp\ipykernel_7520\2530358840.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df_co2["Transmission"], y=df_co2["CO2 Emissions(g/km)"], palette="Set2")
# C:\Users\Infinix X2\AppData\Local\Temp\ipykernel_7520\2530358840.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=lowest_co2_makes, y=lowest_co2_makes.index, palette="Greens_r")
# C:\Users\Infinix X2\AppData\Local\Temp\ipykernel_7520\2530358840.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...
